# %% [markdown]
# ### Regan Alt - Assignment 1 - 06/08/2021

# %%
#import packages
import pandas as pd

# %%
# 1) read the data from a csv file into a DataFrame
asofdate = "20201102"
filename = "SP500_Constituents_"+asofdate+".csv"
data = pd.read_csv(filename)

# %%
# 1) (a) extract the data indicating that the Symbol column is to be the index
data2 = pd.read_csv(filename,
                    index_col="Symbol")

# %%
# 2) Display the first row of the data
data.head(1)
# Out:
#   Symbol    Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM  3M Company     reports  Industrials  Industrial Conglomerates
#
#   Headquarters Location Date first added    CIK Founded
# 0   St. Paul, Minnesota       1976-08-09  66740    1902

# %%
# 3) Determine how many rows are in the data
len(data)
# Out:
# 505

# %%
# 4) Determine the columns with missing values
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 505 entries, MMM to ZTS
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Security               505 non-null    object
#  1   SEC filings            505 non-null    object
#  2   GICS Sector            505 non-null    object
#  3   GICS Sub-Industry      505 non-null    object
#  4   Headquarters Location  505 non-null    object
#  5   Date first added       450 non-null    object
#  6   CIK                    505 non-null    int64
#  7   Founded                502 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 35.5+ KB

# %% [markdown]
# The columns with missing values are "Date first added" and "Founded".

# %%
# 5) Use the loc[] method to display the information about Microsoft (symbol=MSFT).
data2.loc["MSFT"]
# Out:
# Security                        Microsoft Corp.
# SEC filings                             reports
# GICS Sector              Information Technology
# GICS Sub-Industry              Systems Software
# Headquarters Location       Redmond, Washington
# Date first added                     1994-06-01
# CIK                                      789019
# Founded                                    1975
# Name: MSFT, dtype: object

# %%
# 6) What are the distinct values within the column 'GICS Sector'?
# created a list of GICS Sector and called on unique values
list(data["GICS Sector"].unique())
# Out:
# ['Industrials',
#  'Health Care',
#  'Information Technology',
#  'Communication Services',
#  'Consumer Discretionary',
#  'Utilities',
#  'Financials',
#  'Materials',
#  'Real Estate',
#  'Consumer Staples',
#  'Energy']

# %%
# 7) How many stocks are there in each of the GICS Sectors?
# group by with sort
data.groupby('GICS Sector')["Symbol"].count().sort_values()
# Out:
# GICS Sector
# Energy                    25
# Communication Services    26
# Materials                 28
# Utilities                 28
# Real Estate               31
# Consumer Staples          32
# Consumer Discretionary    61
# Health Care               63
# Financials                65
# Industrials               73
# Information Technology    73
# Name: Symbol, dtype: int64

# %%
# 8) Use a filter expression to display the rows where the company is in the Communication Services sector.
data2[data2["GICS Sector"] == "Communication Services"]
# Out:
#                          Security SEC filings             GICS Sector  \
# Symbol
# ATVI          Activision Blizzard     reports  Communication Services
# GOOGL     Alphabet Inc. (Class A)     reports  Communication Services
# GOOG      Alphabet Inc. (Class C)     reports  Communication Services
# T                       AT&T Inc.     reports  Communication Services
# CHTR       Charter Communications     reports  Communication Services
# CMCSA               Comcast Corp.     reports  Communication Services
# DISCA   Discovery, Inc. (Class A)     reports  Communication Services
# DISCK   Discovery, Inc. (Class C)     reports  Communication Services
# DISH                 Dish Network     reports  Communication Services
# EA                Electronic Arts     reports  Communication Services
# FB                 Facebook, Inc.     reports  Communication Services
# FOXA    Fox Corporation (Class A)     reports  Communication Services
# ...

# %%
# 9) Use sort_values() to order to data for Communication Services companies, sorting based on the 'Date first added'. 
# What company was added first, what company was added most recently? 
# assign variable to narrowed down data where it is just Communication Services in the GICS Sector
newoldsp500 =data2[data2["GICS Sector"] == "Communication Services"]
# Sort the data by "Date first added"
newoldsp500.sort_values('Date first added')
# Out:
#                          Security SEC filings             GICS Sector  \
# Symbol
# DIS       The Walt Disney Company     reports  Communication Services
# VZ         Verizon Communications     reports  Communication Services
# T                       AT&T Inc.     reports  Communication Services
# IPG             Interpublic Group     reports  Communication Services
# LUMN           Lumen Technologies     reports  Communication Services
# EA                Electronic Arts     reports  Communication Services
# GOOG      Alphabet Inc. (Class C)     reports  Communication Services
# DISCA   Discovery, Inc. (Class A)     reports  Communication Services
# NFLX                 Netflix Inc.     reports  Communication Services
# FOXA    Fox Corporation (Class A)     reports  Communication Services
# NWSA           News Corp. Class A     reports  Communication Services
# FB                 Facebook, Inc.     reports  Communication Services
# ...

# %% [markdown]
# The oldest company within the GICS Sector in the SP500 is Walt Disney Company which was added in 1976. The newest company within the GICS Sector of Communication Services in the SP500 is ViacomCBS, which has a null value for year but was likely added in 2020.

# %%
# 10) Using isna() and column selection, display the Symbol, Security, and Founded for those companies that are missing data for Data first added.
# assign variable to the stocks where there is no value in the "Date first added column"
nulldateadded = data[data["Date first added"].isna()]
# select desired columns 
nulldateadded[["Symbol","Date first added", "Security", "Founded"]]
# Out:
#     Symbol Date first added                  Security           Founded
# 123     ED              NaN       Consolidated Edison              1823
# 127    GLW              NaN              Corning Inc.              1851
# 135    DHR              NaN             Danaher Corp.              1969
# 136    DRI              NaN        Darden Restaurants              1938
# 151      D              NaN           Dominion Energy              1983
# 161    ETN              NaN         Eaton Corporation              1911
# 162   EBAY              NaN                 eBay Inc.              1995
# 177     ES              NaN         Eversource Energy              1966
# 190   FITB              NaN       Fifth Third Bancorp              1858
# 191     FE              NaN          FirstEnergy Corp              1997
# 204    BEN              NaN        Franklin Resources              1947
# 205    FCX              NaN     Freeport-McMoRan Inc.              1912
# ...
