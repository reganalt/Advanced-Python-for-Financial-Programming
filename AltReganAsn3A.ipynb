# %% [markdown]
# ### Regan Alt - Assignment 3 Part A - 06/22/2021

# %% [markdown]
# ### 1) Call the read_html() function to get all HTML tables from the above web page. How many tables are returned?

# %%
#import packages
import pandas as pd

# %%
# use pandas read_html() function to read all tables from a web page
url = 'https://www.treasury.gov/resource-center/data-chart-center/interest-rates/pages/TextView.aspx?data=yieldYear&year=2021'
data = pd.read_html(url)
print(type(data))
# Out:
# <class 'list'>

# %% [markdown]
# ### 2) Determine which of the returned tables in the list is the table of interest rates over time (e.g., the table at index 0, or index 1, etc.).

# %%
# list of DataFrames are returned from read_html()
for df in data:
    print(type(df))
    
#There are 8 dataframes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# interactively check what the tables are that were returned in the list
data[0]
# Out:
#                                                    0
# 0  These data are also available in XML format by...

# %%
# check index 1
data[1]
# Out:
#          Date  1 mo  2 mo  3 mo  6 mo  1 yr  2 yr  3 yr  5 yr  7 yr  10 yr  \
# 0    01/04/21  0.09  0.09  0.09  0.09  0.10  0.11  0.16  0.36  0.64   0.93
# 1    01/05/21  0.08  0.09  0.09  0.09  0.10  0.13  0.17  0.38  0.66   0.96
# 2    01/06/21  0.09  0.09  0.09  0.09  0.11  0.14  0.20  0.43  0.74   1.04
# 3    01/07/21  0.09  0.09  0.09  0.09  0.11  0.14  0.22  0.46  0.78   1.08
# 4    01/08/21  0.08  0.08  0.08  0.09  0.10  0.14  0.24  0.49  0.81   1.13
# ..        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 113  06/15/21  0.02  0.02  0.03  0.05  0.08  0.16  0.34  0.79  1.21   1.51
# 114  06/16/21  0.04  0.04  0.04  0.06  0.08  0.21  0.41  0.89  1.29   1.57
# 115  06/17/21  0.05  0.04  0.04  0.06  0.08  0.23  0.43  0.90  1.27   1.52
# 116  06/18/21  0.05  0.05  0.05  0.06  0.09  0.26  0.47  0.89  1.22   1.45
# 117  06/21/21  0.04  0.04  0.05  0.06  0.09  0.27  0.48  0.90  1.25   1.50
#
#      20 yr  30 yr
# 0     1.46   1.66
# 1     1.49   1.70
# ...

# %%
# check index 2
data[2]
# Out:
#                                   0
# 0  Related Offices  Debt Management

# %%
# check index 3
data[3]
# Out:
#                                                    0
# 0  Contact Us  Department of the Treasury  1500 P...

# %%
# check index 4
data[4]
# Out:
#                                    0
# 0  View Treasury Auctions Untitled 1

# %%
# check index 5
data[5]
# Out:
#                                                    0
# 0  .style1 { \tmargin-left: 0px; \tmargin-right: ...

# %%
# check index 6
data[6]
# Out:
#                                                    0
# 0  Untitled 1  Bureaus  Alcohol and Tobacco Tax a...

# %%
# check index 7
data[7]
# Out:
#                                                    0
# 0  Required Plug-ins  Privacy Policy |  Google Pr...

# %% [markdown]
# #### ANSWER: The table with the data for interest rates over time is in dataframe [1]

# %% [markdown]
# ### 3) From the list of returned DataFrames, set the DataFrame with the interest rates into its own variable (intrate)

# %%
# To get the table of interest rates over time from the web page via pandas read_html()
# target the table of interest using HTML element attributes
# the interest rates <table> has class=t-chart
intrate = pd.read_html(url, attrs={"class":"t-chart"})
#intrate = pd.DataFrame(data[1])
len(intrate)
# Out:
# 1

# %%
#print intrate
intrate[0]
# Out:
#          Date  1 mo  2 mo  3 mo  6 mo  1 yr  2 yr  3 yr  5 yr  7 yr  10 yr  \
# 0    01/04/21  0.09  0.09  0.09  0.09  0.10  0.11  0.16  0.36  0.64   0.93
# 1    01/05/21  0.08  0.09  0.09  0.09  0.10  0.13  0.17  0.38  0.66   0.96
# 2    01/06/21  0.09  0.09  0.09  0.09  0.11  0.14  0.20  0.43  0.74   1.04
# 3    01/07/21  0.09  0.09  0.09  0.09  0.11  0.14  0.22  0.46  0.78   1.08
# 4    01/08/21  0.08  0.08  0.08  0.09  0.10  0.14  0.24  0.49  0.81   1.13
# ..        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 113  06/15/21  0.02  0.02  0.03  0.05  0.08  0.16  0.34  0.79  1.21   1.51
# 114  06/16/21  0.04  0.04  0.04  0.06  0.08  0.21  0.41  0.89  1.29   1.57
# 115  06/17/21  0.05  0.04  0.04  0.06  0.08  0.23  0.43  0.90  1.27   1.52
# 116  06/18/21  0.05  0.05  0.05  0.06  0.09  0.26  0.47  0.89  1.22   1.45
# 117  06/21/21  0.04  0.04  0.05  0.06  0.09  0.27  0.48  0.90  1.25   1.50
#
#      20 yr  30 yr
# 0     1.46   1.66
# 1     1.49   1.70
# ...

# %%
# turning the interest rate table to a dataframe
df = intrate[0]
df.head()
# Out:
#        Date  1 mo  2 mo  3 mo  6 mo  1 yr  2 yr  3 yr  5 yr  7 yr  10 yr  \
# 0  01/04/21  0.09  0.09  0.09  0.09  0.10  0.11  0.16  0.36  0.64   0.93
# 1  01/05/21  0.08  0.09  0.09  0.09  0.10  0.13  0.17  0.38  0.66   0.96
# 2  01/06/21  0.09  0.09  0.09  0.09  0.11  0.14  0.20  0.43  0.74   1.04
# 3  01/07/21  0.09  0.09  0.09  0.09  0.11  0.14  0.22  0.46  0.78   1.08
# 4  01/08/21  0.08  0.08  0.08  0.09  0.10  0.14  0.24  0.49  0.81   1.13
#
#    20 yr  30 yr
# 0   1.46   1.66
# 1   1.49   1.70
# 2   1.60   1.81
# 3   1.64   1.85
# 4   1.67   1.87

# %% [markdown]
# ### 4) For the DataFrame in step #3, set the Date column to be the row names (index). Display this DataFrame.

# %%
# read data indicating that the Date column is to be the index
data2 = df.set_index("Date")
data2
# Out:
#           1 mo  2 mo  3 mo  6 mo  1 yr  2 yr  3 yr  5 yr  7 yr  10 yr  20 yr  \
# Date
# 01/04/21  0.09  0.09  0.09  0.09  0.10  0.11  0.16  0.36  0.64   0.93   1.46
# 01/05/21  0.08  0.09  0.09  0.09  0.10  0.13  0.17  0.38  0.66   0.96   1.49
# 01/06/21  0.09  0.09  0.09  0.09  0.11  0.14  0.20  0.43  0.74   1.04   1.60
# 01/07/21  0.09  0.09  0.09  0.09  0.11  0.14  0.22  0.46  0.78   1.08   1.64
# 01/08/21  0.08  0.08  0.08  0.09  0.10  0.14  0.24  0.49  0.81   1.13   1.67
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 06/15/21  0.02  0.02  0.03  0.05  0.08  0.16  0.34  0.79  1.21   1.51   2.12
# 06/16/21  0.04  0.04  0.04  0.06  0.08  0.21  0.41  0.89  1.29   1.57   2.13
# 06/17/21  0.05  0.04  0.04  0.06  0.08  0.23  0.43  0.90  1.27   1.52   2.05
# 06/18/21  0.05  0.05  0.05  0.06  0.09  0.26  0.47  0.89  1.22   1.45   1.97
# 06/21/21  0.04  0.04  0.05  0.06  0.09  0.27  0.48  0.90  1.25   1.50   2.05
#
#           30 yr
# Date
# ...

# %% [markdown]
# ### 5) From the table of yields (one row for each date), extract the latest yields into a Python list. This is the last row of the table. (The particular date will depend on when you run your program.)

# %%
# what are the latest yields?
#extract data from last row and assign to list "maxdate"
maxdate = data2.iloc[-1].tolist()
maxdate
# Out:
# [0.04, 0.04, 0.05, 0.06, 0.09, 0.27, 0.48, 0.9, 1.25, 1.5, 2.05, 2.11]

# %% [markdown]
# ### 6) Plot the latest yield curve. This is a scatter chart with yields (in percent) on the Y axis, and time (in years) on the X axis. Time should be represented as a numeric list, e.g., time = [1/12, 2/12, …, 30]

# %%
#import packages
import matplotlib.pyplot as plt
import pandas as pd

# %%
# create a scatter plot with x: Time (in years) & y: Yields (in percent)
# compare the performance of the latest yields over time
periods = ['1/12', '2/12', '3/12', '6/12', '1', '2', '3', '5', '7', '10', '20', '30']
x_top = periods
y_top = maxdate
labels_top = maxdate

# Create the figure and axes objects
fig, ax = plt.subplots(1, figsize=(12, 8))

# Plot the scatter points
ax.scatter(x_top, y_top)

# Add the participant names as text labels for each point
for x_pos, y_pos, label in zip(x_top, y_top, labels_top):
    ax.annotate(label,             # The label for this point
                xy=(x_pos, y_pos), # Position of the corresponding point
                xytext=(10, 5),    
                textcoords='offset points', # tell it to use offset points
                ha='left',         # Horizontally aligned to the left
                va='center')       # Vertical alignment is centered
plt.title('Latest Yields as of 06/21/21')
plt.xlabel('Time (in years)')
plt.ylabel('Yields (as percent)')
plt.show()

# %% [markdown]
# ### 7) Plot the time series of the 2 year and 10 year yields. These are the values in the columns labels '2 yr' and '10 yr'.

# %%
#import packages
import random
import pandas as pd
import matplotlib.pyplot as plt

#define x and y using columns from data
x = data2['2 yr']
y = data2['10 yr']

# Create dataframes of 2 yr and 10 yr interest rate values
df1 = pd.DataFrame(data={'2 yr': x})
df2 = pd.DataFrame(data={'10 yr': y})

# Create matplotlib.axes object so 2 yr and 10 yr interest rates data is on same axis
df1_ax = df1.plot()
df2.plot(ax=df1_ax)

#print chart
plt.title('Yield Returns for 2 year and 10 year Treasury Interest Rates')
plt.show()
